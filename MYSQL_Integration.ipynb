# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\programdata\anaconda2\lib\site-packages (8.0.28)
# Requirement already satisfied: protobuf>=3.0.0 in c:\users\it_pl_ii_cabinno_2\appdata\roaming\python\python38\site-packages (from mysql-connector-python) (3.19.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
db_config = {
    'user': 'root',           
    'password': 'root',       # password for mysql
    'host': 'localhost',
    'database':'mydatabase'   # database name
}

# %%
connection = mysql.connector.connect(**db_config)
# create a connection object

# %%
# creating cursor
'''
a cursor is a mechanism that enables you to traverse the records 
in a database result set. It acts as a pointer or an iterator that 
allows you to move through the rows of a query result and manipulate 
the data.
'''
cursor = connection.cursor()

# %%
insert_query = "insert into users1(username,email) values (%s,%s)"

# %%
users_data = [
    ('akash', 'akash@xyz.com'),
    ('raj', 'raj@xyz.com')
]

# %%
# execution
cursor.executemany(insert_query, users_data)

# %%
# commiting the changes
connection.commit()

# %%
cursor.execute("select * from users1")

# %%
# getting the result from cursor
result = cursor.fetchall()
result
# Out:
# [('akash', 'akash@xyz.com'),
#  ('raj', 'raj@xyz.com'),
#  ('akash', 'akash@xyz.com'),
#  ('raj', 'raj@xyz.com')]

# %%
# need to close the connection manually
cursor.close()
connection.close()

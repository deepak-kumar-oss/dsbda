# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('airquality.csv')

# %%
df['Ozone'].plot()
# Out:
# <Axes: >

# %%
df['Month'].value_counts().plot(kind='pie',autopct='%1.1f%%',startangle=140)
# Out:
# <Axes: ylabel='count'>

# %%
sns.scatterplot(x='Wind',y='Ozone',data=df)
# Out:
# <Axes: xlabel='Wind', ylabel='Ozone'>

# %%
sns.barplot(x='Month',y='Ozone',data=df)
plt.title('wind vs ozone')
plt.show()

# %%
sns.boxplot(x='Month',y='Ozone',data=df)
# Out:
# <Axes: xlabel='Month', ylabel='Ozone'>

# %%
sns.histplot(df['Ozone'].dropna(),bins=20,kde=True)
# Out:
# <Axes: xlabel='Ozone', ylabel='Count'>

# %%
numeric_cols=df.select_dtypes(include=np.number).columns
corr=df[numeric_cols].corr()
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >
